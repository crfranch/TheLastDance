# %%
# Import the Pandas library
import pandas as pd
import numpy as np

# %%
# Create a reference the CSV file desired
csv_path = "Resources/TopCoaches.csv"

# Read the CSV into a Pandas DataFrame
BestNBACoaches_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
BestNBACoaches_df.head()
# Remove all null values
BestNBACoaches_df.dropna()
# Out:
#              Coach                  Team(s) coached (years)[a]  \
# 0   Lenny Wilkens*  Seattle SuperSonics (1969–1972, 1977–1985)
# 6       Pat Riley*              Los Angeles Lakers (1981–1990)
# 9     Jack Ramsay*              Philadelphia 76ers (1968–1972)
# 13     Don Nelson*                 Milwaukee Bucks (1976–1987)
# 17    John Kundla*              Minneapolis Lakers (1948–1959)
# 18   Phil Jackson*                   Chicago Bulls (1989–1998)
# 20    Red Holzman*     Milwaukee / St. Louis Hawks (1954–1956)
# 22     Bill Fitch*             Cleveland Cavaliers (1970–1979)
# 27     Chuck Daly*                  Cleveland Cavaliers (1982)
# 31   Red Auerbach*             Washington Capitols (1946–1949)
#
#     Coaching record                      Championships won as coach[b]  \
# 0   1014–850 (.544)                                           1 (1979)
# 6    798–339 (.702)                   5 (1982, 1985, 1987, 1988, 2006)
# ...

# %%
# Import Dependencies 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Plot the charts and apply some styling
coach_name = plt.plot(BestNBACoaches_df, color="red", label="Coach")
coaching_record = plt.plot(BestNBACoaches_df, color="blue", label="Coaching record")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-41f0b496ae92> in <module>
#       1 # Plot the charts and apply some styling
# ----> 2 coach_name = plt.plot(BestNBACoaches_df, color="red", label="Coach")
#       3 coaching_record = plt.plot(BestNBACoaches_df, color="blue", label="Coaching record")
#
# ~\anaconda\Anaconda3\envs\LastDance\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\anaconda\Anaconda3\envs\LastDance\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
